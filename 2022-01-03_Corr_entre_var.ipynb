# %% [markdown]
# en fondos oscuros
# from jupyterthemes import jtplot
# jtplot.style

# %% [markdown]
# ## Ver correlación entre variables

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use("seaborn-dark")

iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# scatterplot
sns.scatterplot(data=iris, x='sepal_length', y='petal_length', hue='species')
plt.grid()
plt.show()

# %%
# joint plot
sns.jointplot(data=iris, x='sepal_length', y='petal_length', hue='species')
plt.show()

# %%
# box plot
sns.boxplot(data=iris, x='species', y='sepal_length')
plt.show()

# %%
# bar plot
sns.barplot(data=iris, x='species', y='sepal_length')
plt.show()

# %%
# esto no se hace, el hue solo pinta, no filtra:
# joint plot
sns.jointplot(data=iris, 
              x='petal_length', 
              y='sepal_length', 
              hue='species' == 'setosa')
plt.show()

# %%
# generando el df de setosa
iris_setosa = iris[iris['species'] == 'setosa']

iris_setosa
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
# joint plot
sns.jointplot(data=iris_setosa, x='petal_length', y='sepal_length')
plt.show()
