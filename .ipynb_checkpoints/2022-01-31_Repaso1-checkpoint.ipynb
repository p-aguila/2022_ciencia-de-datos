# %%
# %load_ext watermark
# %watermark
# Out:
# Last updated: 2022-01-31T16:44:13.838112-03:00
#
# Python implementation: CPython
# Python version       : 3.8.12
# IPython version      : 7.29.0
#
# Compiler    : MSC v.1916 64 bit (AMD64)
# OS          : Windows
# Release     : 10
# Machine     : AMD64
# Processor   : Intel64 Family 6 Model 158 Stepping 10, GenuineIntel
# CPU cores   : 12
# Architecture: 64bit

# %%
# exploracion visual
from IPython.core.display import display, HTML
display(HTML("<style>.container{width:98%}</style>"))
# Out:
# <style>.container{width:98%}</style>

# %%
import pandas as pd

# %%
filename = '../Ejercicios_Propios/datasets/pima-indians-diabetes.csv'
nombres = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
df = pd.read_csv(filename, names=nombres)
df
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  class
# 0       6   148    72    35     0  33.6  0.627   50      1
# 1       1    85    66    29     0  26.6  0.351   31      0
# 2       8   183    64     0     0  23.3  0.672   32      1
# 3       1    89    66    23    94  28.1  0.167   21      0
# 4       0   137    40    35   168  43.1  2.288   33      1
# ..    ...   ...   ...   ...   ...   ...    ...  ...    ...
# 763    10   101    76    48   180  32.9  0.171   63      0
# 764     2   122    70    27     0  36.8  0.340   27      0
# 765     5   121    72    23   112  26.2  0.245   30      0
# 766     1   126    60     0     0  30.1  0.349   47      1
# 767     1    93    70    31     0  30.4  0.315   23      0
#
# [768 rows x 9 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use("seaborn-dark")
fig = plt.figure(figsize=(10, 10))
ax = fig.gca()
df.hist(ax=ax)
plt.show()
# Out:
# C:\Users\patri\AppData\Local\Temp/ipykernel_13136/1870651481.py:6: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   df.hist(ax=ax)

# %%
# graficos boxplot
fig = plt.figure(figsize=(16, 16))
ax = fig.gca()
df.plot(ax=ax, kind='box', subplots=True, layout=(3, 3))
plt.show()
# Out:
# C:\Users\patri\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   plot_obj.generate()

# %%
# matriz de correlacion
correlaciones = df.corr()
correlaciones
# Out:
#            preg      plas      pres      skin      test      mass      pedi  \
# preg   1.000000  0.129459  0.141282 -0.081672 -0.073535  0.017683 -0.033523
# plas   0.129459  1.000000  0.152590  0.057328  0.331357  0.221071  0.137337
# pres   0.141282  0.152590  1.000000  0.207371  0.088933  0.281805  0.041265
# skin  -0.081672  0.057328  0.207371  1.000000  0.436783  0.392573  0.183928
# test  -0.073535  0.331357  0.088933  0.436783  1.000000  0.197859  0.185071
# mass   0.017683  0.221071  0.281805  0.392573  0.197859  1.000000  0.140647
# pedi  -0.033523  0.137337  0.041265  0.183928  0.185071  0.140647  1.000000
# age    0.544341  0.263514  0.239528 -0.113970 -0.042163  0.036242  0.033561
# class  0.221898  0.466581  0.065068  0.074752  0.130548  0.292695  0.173844
#
#             age     class
# preg   0.544341  0.221898
# plas   0.263514  0.466581
# pres   0.239528  0.065068
# skin  -0.113970  0.074752
# test  -0.042163  0.130548
# mass   0.036242  0.292695
# ...

# %%
import numpy as np

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(correlaciones, vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0, 9, 1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(nombres)
ax.set_yticklabels(nombres)
plt.show()

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10, 10))
ax = sns.heatmap(correlaciones, vmax=1, square=True, annot=True, cmap='viridis')

# %%
from pandas.plotting import scatter_matrix
plt.rcParams['figure.figsize'] = [15,15]
scatter_matrix(df)
plt.show()

# %%
sns.pairplot(df, hue='class', diag_kind='hist')
plt.show()
